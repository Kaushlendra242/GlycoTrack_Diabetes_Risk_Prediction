# %% [markdown]
# # PO69_GlycoTrack_Analysis_Report
#
# Client-facing analysis notebook (run to generate visuals).

# %%
import pandas as pd
import os
print('Loading cleaned dataset...')
df = pd.read_csv('CDC_Diabetes_Health_Indicators_Cleaned.csv')
print(df.shape)
# Out:
# Loading cleaned dataset...
# (72776, 22)

# %% [markdown]
# ## Key visuals
# Run code to generate report visuals (BMI distribution, correlation heatmap, model ROC).

# %%
import matplotlib.pyplot as plt, seaborn as sns
if 'BMI' in df.columns:
    plt.figure(figsize=(6,3)); sns.histplot(df['BMI'].dropna(), bins=30); plt.title('BMI (cleaned)'); plt.savefig(os.path.join('plots','EDA','report_BMI.png')); plt.close(); print('Saved report_BMI.png')
# Out:
# Saved report_BMI.png
